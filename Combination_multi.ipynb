# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/MUTAG/"
kernel_grid = ['WL', 'RW']
dim_hidden = [64]
num_head = 2
wl_grid = [1,2,3]
layer_grid = [1, 2, 3, 4, 5, 6]
hop_grid = [1, 2, 3]
bs_grid = [64]
drop_grid = [0.0]
lr_grid = [0.001]
lap=False
GL = 5

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}l_{}h_{}_{}_{}/results.csv'.format(fold, num_head, lap, kernel_grid[0], kernel_grid[1], dim, wl, GL, layer, hop, drop, lr, bs)
                                if not os.path.exists(path):
                                    continue
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'RW'], 'wl': 3, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.111 best test acc:0.5789473684210527
# 20.447975158691406
# Best combination for fold 2: {'kernel': ['WL', 'RW'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.367 best test acc:0.7368421052631579
# 18.62026882171631
# Best combination for fold 3: {'kernel': ['WL', 'RW'], 'wl': 3, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.263 best test acc:0.9473684210526316
# 22.813913345336918
# Best combination for fold 4: {'kernel': ['WL', 'RW'], 'wl': 3, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.169 best test acc:0.7368421052631579
# 22.626893043518063
# Best combination for fold 5: {'kernel': ['WL', 'RW'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.49 best test acc:0.9473684210526316
# 14.14066767692566
# Best combination for fold 6: {'kernel': ['WL', 'RW'], 'wl': 3, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.076 best test acc:0.7368421052631579
# 20.758249759674072
# Best combination for fold 7: {'kernel': ['WL', 'RW'], 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.121 best test acc:0.8947368421052632
# 10.923048496246338
# Best combination for fold 8: {'kernel': ['WL', 'RW'], 'wl': 2, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.069 best test acc:0.8947368421052632
# 42.3007128238678
# Best combination for fold 9: {'kernel': ['WL', 'RW'], 'wl': 2, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.095 best test acc:0.7222222222222222
# 15.588687658309937
# Best combination for fold 10: {'kernel': ['WL', 'RW'], 'wl': 2, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.357 best test acc:0.7222222222222222
# 15.83120584487915
# Test accuracy mean: 0.7918128654970761
# Test accuracy standard deviation: 0.036557426085599025
# [20.447975158691406, 18.62026882171631, 22.813913345336918, 22.626893043518063, 14.14066767692566, 20.758249759674072, 10.923048496246338, 42.3007128238678, 15.588687658309937, 15.83120584487915]
# time cost: 20.41+/-2.58

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/MUTAG/"
kernel_grid = ['WL', 'SP']
dim_hidden = [64]
num_head = 2
wl_grid = [1,2,3]
layer_grid = [1, 2, 3, 4, 5, 6]
hop_grid = [1, 2, 3]
bs_grid = [64]
drop_grid = [0.0]
lr_grid = [0.001]
lap=False
GL = 5

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}l_{}h_{}_{}_{}/results.csv'.format(fold, num_head, lap, kernel_grid[0], kernel_grid[1], dim, wl, GL, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.113 best test acc:0.5789473684210527
# 14.29115080833435
# Best combination for fold 2: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.365 best test acc:0.8947368421052632
# 20.60275077819824
# Best combination for fold 3: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.25 best test acc:0.9473684210526316
# 20.78348278999329
# Best combination for fold 4: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.19 best test acc:0.7368421052631579
# 18.36546421051025
# Best combination for fold 5: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.401 best test acc:0.8947368421052632
# 16.00627613067627
# Best combination for fold 6: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 4, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.093 best test acc:0.7368421052631579
# 11.90158724784851
# Best combination for fold 7: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 4, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.141 best test acc:0.8421052631578947
# 18.39030861854553
# Best combination for fold 8: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.083 best test acc:0.8947368421052632
# 24.475390434265137
# Best combination for fold 9: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.063 best test acc:0.8888888888888888
# 25.73105025291443
# Best combination for fold 10: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.37 best test acc:0.8333333333333334
# 18.75094437599182
# Test accuracy mean: 0.8248538011695906
# Test accuracy standard deviation: 0.03318024247677656
# [14.29115080833435, 20.60275077819824, 20.78348278999329, 18.36546421051025, 16.00627613067627, 11.90158724784851, 18.39030861854553, 24.475390434265137, 25.73105025291443, 18.75094437599182]
# time cost: 18.93+/-1.28

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/MUTAG/"
kernel_grid = ['RW']
dim_hidden = [64]
num_head = 1
wl_grid = [1,2,3]
layer_grid = [1, 2, 3, 4, 5, 6]
hop_grid = [1, 2, 3]
bs_grid = [64]
drop_grid = [0.0]
lr_grid = [0.001]
lap=False
GL = 5

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}l_{}h_{}_{}_{}/results.csv'.format(fold, num_head, lap, kernel_grid[0], dim, wl, GL, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['RW'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.21 best test acc:0.6842105263157895
# 16.59750461578369
# Best combination for fold 2: {'kernel': ['RW'], 'wl': 1, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.395 best test acc:0.7894736842105263
# 18.80910634994507
# Best combination for fold 3: {'kernel': ['RW'], 'wl': 1, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.287 best test acc:1.0
# 18.12494111061096
# Best combination for fold 4: {'kernel': ['RW'], 'wl': 1, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.139 best test acc:0.6842105263157895
# 24.947238445281982
# Best combination for fold 5: {'kernel': ['RW'], 'wl': 1, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.365 best test acc:0.5789473684210527
# 20.57090735435486
# Best combination for fold 6: {'kernel': ['RW'], 'wl': 1, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.144 best test acc:0.7368421052631579
# 17.61386466026306
# Best combination for fold 7: {'kernel': ['RW'], 'wl': 1, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.138 best test acc:0.8421052631578947
# 27.6345899105072
# Best combination for fold 8: {'kernel': ['RW'], 'wl': 1, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.126 best test acc:0.8947368421052632
# 25.406180381774902
# Best combination for fold 9: {'kernel': ['RW'], 'wl': 1, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.076 best test acc:0.7222222222222222
# 16.95368790626526
# Best combination for fold 10: {'kernel': ['RW'], 'wl': 1, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.39 best test acc:0.6666666666666666
# 15.344688653945925
# Test accuracy mean: 0.7599415204678364
# Test accuracy standard deviation: 0.03718960317871286
# [16.59750461578369, 18.80910634994507, 18.12494111061096, 24.947238445281982, 20.57090735435486, 17.61386466026306, 27.6345899105072, 25.406180381774902, 16.95368790626526, 15.344688653945925]
# time cost: 20.20+/-1.28

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/MUTAG/"
kernel_grid = ['SP']
dim_hidden = [64]
num_head = 1
wl_grid = [1,2,3]
layer_grid = [1, 2, 3, 4, 5, 6]
hop_grid = [1, 2, 3]
bs_grid = [64]
drop_grid = [0.0]
lr_grid = [0.001]
lap=False
GL = 5

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}l_{}h_{}_{}_{}/results.csv'.format(fold, num_head, lap, kernel_grid[0], dim, wl, GL, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['SP'], 'wl': 1, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.176 best test acc:0.631578947368421
# 19.26595616340637
# Best combination for fold 2: {'kernel': ['SP'], 'wl': 1, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.444 best test acc:0.8947368421052632
# 12.699798583984377
# Best combination for fold 3: {'kernel': ['SP'], 'wl': 1, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.294 best test acc:1.0
# 10.32599639892578
# Best combination for fold 4: {'kernel': ['SP'], 'wl': 1, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.174 best test acc:0.7368421052631579
# 18.8015239238739
# Best combination for fold 5: {'kernel': ['SP'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.506 best test acc:0.7894736842105263
# 13.53813123703003
# Best combination for fold 6: {'kernel': ['SP'], 'wl': 1, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.088 best test acc:0.7368421052631579
# 16.655744314193726
# Best combination for fold 7: {'kernel': ['SP'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.125 best test acc:0.8947368421052632
# 20.127888679504395
# Best combination for fold 8: {'kernel': ['SP'], 'wl': 1, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.126 best test acc:0.8947368421052632
# 32.10557818412781
# Best combination for fold 9: {'kernel': ['SP'], 'wl': 1, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.088 best test acc:0.7777777777777778
# 15.01238179206848
# Best combination for fold 10: {'kernel': ['SP'], 'wl': 1, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.392 best test acc:0.8333333333333334
# 9.549847602844238
# Test accuracy mean: 0.8190058479532164
# Test accuracy standard deviation: 0.031839003924815035
# [19.26595616340637, 12.699798583984377, 10.32599639892578, 18.8015239238739, 13.53813123703003, 16.655744314193726, 20.127888679504395, 32.10557818412781, 15.01238179206848, 9.549847602844238]
# time cost: 16.81+/-1.95

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/MUTAG/"
kernel_grid = ['GL']
dim_hidden = [64]
num_head = 1
wl_grid = [1,2,3,4,5]
layer_grid = [1, 2, 3, 4, 5, 6]
hop_grid = [1, 2, 3]
bs_grid = [64]
drop_grid = [0.0]
lr_grid = [0.001]
lap=False
GL = 5

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}l_{}h_{}_{}_{}/results.csv'.format(fold, num_head, lap, kernel_grid[0], dim, wl, GL, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['GL'], 'wl': 1, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.237 best test acc:0.6842105263157895
# 18.67315125465393
# Best combination for fold 2: {'kernel': ['GL'], 'wl': 1, 'layer': 1, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.431 best test acc:0.8421052631578947
# 9.346333742141724
# Best combination for fold 3: {'kernel': ['GL'], 'wl': 1, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.269 best test acc:1.0
# 15.658230781555176
# Best combination for fold 4: {'kernel': ['GL'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.132 best test acc:0.6842105263157895
# 19.906694412231445
# Best combination for fold 5: {'kernel': ['GL'], 'wl': 1, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.477 best test acc:0.8421052631578947
# 22.112202405929565
# Best combination for fold 6: {'kernel': ['GL'], 'wl': 1, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.167 best test acc:0.7368421052631579
# 11.523656129837036
# Best combination for fold 7: {'kernel': ['GL'], 'wl': 1, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.032 best test acc:0.9473684210526316
# 47.200294494628906
# Best combination for fold 8: {'kernel': ['GL'], 'wl': 1, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.114 best test acc:0.9473684210526316
# 24.70038366317749
# Best combination for fold 9: {'kernel': ['GL'], 'wl': 1, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.063 best test acc:0.8888888888888888
# 29.18976831436157
# Best combination for fold 10: {'kernel': ['GL'], 'wl': 1, 'layer': 4, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.402 best test acc:0.8888888888888888
# 17.995110988616943
# Test accuracy mean: 0.8461988304093568
# Test accuracy standard deviation: 0.03350269889753406
# [18.67315125465393, 9.346333742141724, 15.658230781555176, 19.906694412231445, 22.112202405929565, 11.523656129837036, 47.200294494628906, 24.70038366317749, 29.18976831436157, 17.995110988616943]
# time cost: 21.63+/-3.22

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_CPU/MUTAG/"
kernel_grid = ['WL', 'RW']
wl_grid = [1, 2, 3, 4, 5]
layer_grid = [1, 2, 3]
dim_hidden = [64, 128]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]
num_head = 2


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1,0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                            #         best_test_acc = test_acc
                            #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3451668/3439268285.py in <module>
#      29                             for bs in bs_grid:
#      30                                 path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
# ---> 31                                 df = pd.read_csv(path)
#      32                                 val_loss = df.iloc[:, -1].min()
#      33                                 if val_loss < best_val_loss:
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Output_200_CPU/MUTAG//fold_1/2_WL_RW_64_1_1_1_0.0_0.1_32/results.csv'

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_CPU/MUTAG/"
kernel_grid = ['RW', 'SP']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
dim_hidden = [64, 128]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]
num_head = 2


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1,0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                            #         best_test_acc = test_acc
                            #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.217 best test acc:0.631578947368421
# Best combination for fold 2: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.388 best test acc:0.8421052631578947
# Best combination for fold 3: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.275 best test acc:0.7894736842105263
# Best combination for fold 4: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.252 best test acc:0.6842105263157895
# Best combination for fold 5: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.485 best test acc:0.8947368421052632
# Best combination for fold 6: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.128 best test acc:0.7368421052631579
# Best combination for fold 7: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.148 best test acc:0.7368421052631579
# Best combination for fold 8: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.207 best test acc:0.8947368421052632
# Best combination for fold 9: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.246 best test acc:0.8333333333333334
# Best combination for fold 10: {'kernel': ['RW', 'SP'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.419 best test acc:0.7222222222222222
# Test accuracy mean: 0.776608187134503
# Test accuracy standard deviation: 0.026697043332631832
# time cost: 16.25+/-1.33

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/MUTAG/"
kernel_grid = ['WL', 'GL']
wl_grid = [1, 2, 3, 4, 5]
layer_grid = [1, 2, 3, 4, 5, 6]
dim_hidden = [64, 128]
hop_grid = [1, 2, 3]
bs_grid = [64]
gls = [3, 4, 5]
drop_grid = [0.0]
lr_grid = [0.001]
num_head = 2


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for gl_k in gls:
            for dim in dim_hidden:
                for layer in layer_grid:
                    for hop in hop_grid:
                        for drop in drop_grid:
                            for lr in lr_grid:
                                for bs in bs_grid:
                                    path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, gl_k, layer, hop, drop, lr, bs)
                                    df = pd.read_csv(path)
                                    val_loss = df.iloc[:, -1].min()
                                    if val_loss < best_val_loss:
                                        best_val_loss = val_loss
                                        best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                        best_test_acc = df.iloc[-2, 1]
                                        time = df.iloc[-1,0]
                                    # elif val_acc == best_val_acc:
                                    #     test_acc = df.iloc[-2, 1]
                                    #     if test_acc > best_test_acc:
                            #         best_test_acc = test_acc
                            #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'GL'], 'wl': 1, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.183 best test acc:0.6842105263157895
# Best combination for fold 2: {'kernel': ['WL', 'GL'], 'wl': 1, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.306 best test acc:0.8947368421052632
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3377013/293982718.py in <module>
#      31                                 for bs in bs_grid:
#      32                                     path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, gl_k, layer, hop, drop, lr, bs)
# ---> 33                                     df = pd.read_csv(path)
#      34                                     val_loss = df.iloc[:, -1].min()
#      35                                     if val_loss < best_val_loss:
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Output_200_Adam/MUTAG//fold_3/2_WL_GL_128_2_3_4_3_0.0_0.001_64/results.csv'

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/MUTAG/"
kernel_grid = ['WL', 'GL', 'SP', 'RW']
wl_grid = [1, 2, 3, 4, 5]
layer_grid = [1, 2, 3, 4, 5, 6]
dim_hidden = [128]
hop_grid = [1, 2, 3]
bs_grid = [64]
gls = [5]
drop_grid = [0.0]
lr_grid = [0.001]
num_head = 4


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for gl_k in gls:
            for dim in dim_hidden:
                for layer in layer_grid:
                    for hop in hop_grid:
                        for drop in drop_grid:
                            for lr in lr_grid:
                                for bs in bs_grid:
                                    path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], kernel_grid[2], kernel_grid[3], dim, wl, gl_k, layer, hop, drop)
                                    df = pd.read_csv(path)
                                    val_loss = df.iloc[:, -1].min()
                                    if val_loss < best_val_loss:
                                        best_val_loss = val_loss
                                        best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                        best_test_acc = df.iloc[-2, 1]
                                        time = df.iloc[-1,0]
                                    # elif val_acc == best_val_acc:
                                    #     test_acc = df.iloc[-2, 1]
                                    #     if test_acc > best_test_acc:
                            #         best_test_acc = test_acc
                            #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.076 best test acc:0.7894736842105263
# Best combination for fold 2: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 2, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.231 best test acc:0.8421052631578947
# Best combination for fold 3: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 2, 'layer': 4, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.166 best test acc:0.9473684210526316
# Best combination for fold 4: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.091 best test acc:0.6842105263157895
# Best combination for fold 5: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.209 best test acc:0.7368421052631579
# Best combination for fold 6: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.073 best test acc:0.6842105263157895
# Best combination for fold 7: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 4, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.005 best test acc:0.8947368421052632
# Best combination for fold 8: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.053 best test acc:0.9473684210526316
# Best combination for fold 9: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.011 best test acc:0.7777777777777778
# Best combination for fold 10: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 5, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.261 best test acc:0.9444444444444444
# Test accuracy mean: 0.8248538011695906
# Test accuracy standard deviation: 0.03166668016609411
# time cost: 22.19+/-2.13

# %% [markdown]
# ## PTC

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/PTC_MR/"
kernel_grid = ['RW', 'SP']
dim_hidden = [64, 128]
num_head = 2
wl_grid = [1]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.57 best test acc:0.5428571428571428
# 31.35927963256836
# Best combination for fold 2: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.569 best test acc:0.5428571428571428
# 21.177634954452515
# Best combination for fold 3: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.623 best test acc:0.6285714285714286
# 25.91662573814392
# Best combination for fold 4: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.64 best test acc:0.7142857142857143
# 13.855140924453735
# Best combination for fold 5: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.673 best test acc:0.5294117647058824
# 28.29489207267761
# Best combination for fold 6: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.678 best test acc:0.5
# 13.336514949798584
# Best combination for fold 7: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.495 best test acc:0.5588235294117647
# 26.2932448387146
# Best combination for fold 8: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 1, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.52 best test acc:0.7058823529411765
# 15.213205337524414
# Best combination for fold 9: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.691 best test acc:0.6176470588235294
# 13.760429859161375
# Best combination for fold 10: {'kernel': ['RW', 'SP'], 'wl': 1, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.668 best test acc:0.5
# 28.99814486503601
# Test accuracy mean: 0.5840336134453782
# Test accuracy standard deviation: 0.02367690864760696
# [31.35927963256836, 21.177634954452515, 25.91662573814392, 13.855140924453735, 28.29489207267761, 13.336514949798584, 26.2932448387146, 15.213205337524414, 13.760429859161375, 28.99814486503601]
# time cost: 21.82+/-2.16

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/PTC_MR/"
kernel_grid = ['WL', 'SP']
dim_hidden = [64, 128]
num_head = 2
wl_grid = [1, 2, 3]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.417 best test acc:0.5142857142857142
# 27.045475482940677
# Best combination for fold 2: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.585 best test acc:0.5428571428571428
# 24.95620703697205
# Best combination for fold 3: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.562 best test acc:0.5142857142857142
# 24.889365673065186
# Best combination for fold 4: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.56 best test acc:0.6571428571428571
# 31.50802063941956
# Best combination for fold 5: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 1, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.7 best test acc:0.6764705882352942
# 13.707332611083984
# Best combination for fold 6: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.586 best test acc:0.4411764705882353
# 35.7026641368866
# Best combination for fold 7: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.45 best test acc:0.6470588235294118
# 48.405489444732666
# Best combination for fold 8: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.476 best test acc:0.7058823529411765
# 25.81331944465637
# Best combination for fold 9: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.665 best test acc:0.5882352941176471
# 26.64376902580261
# Best combination for fold 10: {'kernel': ['WL', 'SP'], 'wl': 1, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.647 best test acc:0.5294117647058824
# 29.690539360046387
# Test accuracy mean: 0.5816806722689074
# Test accuracy standard deviation: 0.02597843129855158
# [27.045475482940677, 24.95620703697205, 24.889365673065186, 31.50802063941956, 13.707332611083984, 35.7026641368866, 48.405489444732666, 25.81331944465637, 26.64376902580261, 29.690539360046387]
# time cost: 28.84+/-2.67

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/PTC_MR/"
kernel_grid = ['WL', 'GL', 'SP', 'RW']
wl_grid = [1, 2, 3, 4, 5]
layer_grid = [1, 2, 3, 4, 5, 6]
dim_hidden = [128]
hop_grid = [1, 2, 3]
bs_grid = [64]
gls = [5]
drop_grid = [0.0]
lr_grid = [0.001]
num_head = 4


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for gl_k in gls:
            for dim in dim_hidden:
                for layer in layer_grid:
                    for hop in hop_grid:
                        for drop in drop_grid:
                            for lr in lr_grid:
                                for bs in bs_grid:
                                    path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], kernel_grid[2], kernel_grid[3], dim, wl, gl_k, layer, hop, drop)
                                    df = pd.read_csv(path)
                                    val_loss = df.iloc[:, -1].min()
                                    if val_loss < best_val_loss:
                                        best_val_loss = val_loss
                                        best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                        best_test_acc = df.iloc[-2, 1]
                                        time = df.iloc[-1,0]
                                    # elif val_acc == best_val_acc:
                                    #     test_acc = df.iloc[-2, 1]
                                    #     if test_acc > best_test_acc:
                            #         best_test_acc = test_acc
                            #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.476 best test acc:0.6285714285714286
# Best combination for fold 2: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.484 best test acc:0.3714285714285714
# Best combination for fold 3: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.501 best test acc:0.4571428571428571
# Best combination for fold 4: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.534 best test acc:0.6857142857142857
# Best combination for fold 5: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.489 best test acc:0.5882352941176471
# Best combination for fold 6: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.573 best test acc:0.4705882352941176
# Best combination for fold 7: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.414 best test acc:0.6470588235294118
# Best combination for fold 8: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 4, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.401 best test acc:0.7647058823529411
# Best combination for fold 9: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.629 best test acc:0.7058823529411765
# Best combination for fold 10: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 2, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.557 best test acc:0.7352941176470589
# Test accuracy mean: 0.6054621848739495
# Test accuracy standard deviation: 0.039529978058597315
# time cost: 44.16+/-4.24

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/PTC_MR/"
kernel_grid = ['RW']
dim_hidden = [64, 128]
num_head = 1
wl_grid = [1]
layer_grid = [1, 2, 3, 4, 5, 6]
hop_grid = [1, 2, 3]
bs_grid = [64]
drop_grid = [0.0]
lr_grid = [0.001]
lap=False
GL = 5

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}l_{}h_{}_{}_{}/results.csv'.format(fold, num_head, lap, kernel_grid[0], dim, wl, GL, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['RW'], 'wl': 1, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.586 best test acc:0.6285714285714286
# 30.813981533050537
# Best combination for fold 2: {'kernel': ['RW'], 'wl': 1, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.554 best test acc:0.4571428571428571
# 19.98660945892334
# Best combination for fold 3: {'kernel': ['RW'], 'wl': 1, 'layer': 4, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.656 best test acc:0.6285714285714286
# 23.75727796554565
# Best combination for fold 4: {'kernel': ['RW'], 'wl': 1, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.513 best test acc:0.7142857142857143
# 25.61673784255981
# Best combination for fold 5: {'kernel': ['RW'], 'wl': 1, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.684 best test acc:0.6764705882352942
# 31.52486753463745
# Best combination for fold 6: {'kernel': ['RW'], 'wl': 1, 'layer': 4, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.631 best test acc:0.5294117647058824
# 24.74577260017395
# Best combination for fold 7: {'kernel': ['RW'], 'wl': 1, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.494 best test acc:0.5
# 42.287068128585815
# Best combination for fold 8: {'kernel': ['RW'], 'wl': 1, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.49 best test acc:0.5588235294117647
# 25.63956642150879
# Best combination for fold 9: {'kernel': ['RW'], 'wl': 1, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.687 best test acc:0.5588235294117647
# 21.74565625190735
# Best combination for fold 10: {'kernel': ['RW'], 'wl': 1, 'layer': 4, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.69 best test acc:0.4705882352941176
# 28.6748960018158
# Test accuracy mean: 0.5722689075630252
# Test accuracy standard deviation: 0.02614971588188561
# [30.813981533050537, 19.98660945892334, 23.75727796554565, 25.61673784255981, 31.52486753463745, 24.74577260017395, 42.287068128585815, 25.63956642150879, 21.74565625190735, 28.6748960018158]
# time cost: 27.48+/-1.91

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/PTC_MR/"
kernel_grid = ['GL']
dim_hidden = [64]
num_head = 1
wl_grid = [1,2,3]
layer_grid = [1, 2, 3, 4, 5, 6]
hop_grid = [1, 2, 3]
bs_grid = [64]
drop_grid = [0.0]
lr_grid = [0.001]
lap=False
GL = 5

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}l_{}h_{}_{}_{}/results.csv'.format(fold, num_head, lap, kernel_grid[0], dim, wl, GL, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['GL'], 'wl': 1, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.601 best test acc:0.5428571428571428
# 31.39299464225769
# Best combination for fold 2: {'kernel': ['GL'], 'wl': 1, 'layer': 6, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.531 best test acc:0.5714285714285714
# 37.28617334365845
# Best combination for fold 3: {'kernel': ['GL'], 'wl': 1, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.622 best test acc:0.6571428571428571
# 15.32244038581848
# Best combination for fold 4: {'kernel': ['GL'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.594 best test acc:0.5428571428571428
# 27.388649463653564
# Best combination for fold 5: {'kernel': ['GL'], 'wl': 1, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.639 best test acc:0.5882352941176471
# 24.35273385047913
# Best combination for fold 6: {'kernel': ['GL'], 'wl': 1, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.638 best test acc:0.5294117647058824
# 14.817683696746826
# Best combination for fold 7: {'kernel': ['GL'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.443 best test acc:0.5
# 33.965447187423706
# Best combination for fold 8: {'kernel': ['GL'], 'wl': 1, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.485 best test acc:0.5882352941176471
# 35.00562596321106
# Best combination for fold 9: {'kernel': ['GL'], 'wl': 1, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.656 best test acc:0.6176470588235294
# 19.880127668380737
# Best combination for fold 10: {'kernel': ['GL'], 'wl': 1, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.653 best test acc:0.5882352941176471
# 12.020178079605104
# Test accuracy mean: 0.5726050420168066
# Test accuracy standard deviation: 0.01371741602106737
# [31.39299464225769, 37.28617334365845, 15.32244038581848, 27.388649463653564, 24.35273385047913, 14.817683696746826, 33.965447187423706, 35.00562596321106, 19.880127668380737, 12.020178079605104]
# time cost: 25.14+/-2.78

# %% [markdown]
# ## PROTEINS

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/PROTEINS/"
kernel_grid = ['WL', 'GL', 'SP', 'RW']
wl_grid = [1, 2, 3, 4, 5]
layer_grid = [1, 2, 3, 4, 5, 6]
dim_hidden = [64, 128]
hop_grid = [1, 2, 3]
bs_grid = [64]
gls = [5]
drop_grid = [0.0]
lr_grid = [0.001]
num_head = 4


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for gl_k in gls:
            for dim in dim_hidden:
                for layer in layer_grid:
                    for hop in hop_grid:
                        for drop in drop_grid:
                            for lr in lr_grid:
                                for bs in bs_grid:
                                    path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], kernel_grid[2], kernel_grid[3], dim, wl, gl_k, layer, hop, drop)
                                    df = pd.read_csv(path)
                                    val_loss = df.iloc[:, -1].min()
                                    if val_loss < best_val_loss:
                                        best_val_loss = val_loss
                                        best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                        best_test_acc = df.iloc[-2, 1]
                                        time = df.iloc[-1,0]
                                    # elif val_acc == best_val_acc:
                                    #     test_acc = df.iloc[-2, 1]
                                    #     if test_acc > best_test_acc:
                            #         best_test_acc = test_acc
                            #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 2, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.427 best test acc:0.7410714285714286
# Best combination for fold 2: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.461 best test acc:0.8125
# Best combination for fold 3: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.329 best test acc:0.7232142857142857
# Best combination for fold 4: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 5, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.392 best test acc:0.7387387387387387
# Best combination for fold 5: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.402 best test acc:0.6846846846846847
# Best combination for fold 6: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.476 best test acc:0.7747747747747747
# Best combination for fold 7: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.526 best test acc:0.7387387387387387
# Best combination for fold 8: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 4, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.332 best test acc:0.6666666666666666
# Best combination for fold 9: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 6, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.495 best test acc:0.8288288288288288
# Best combination for fold 10: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 1, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.404 best test acc:0.7117117117117117
# Test accuracy mean: 0.7420929858429859
# Test accuracy standard deviation: 0.015438966532136713
# time cost: 252.99+/-18.27

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/NCI1/"
kernel_grid = ['WL', 'SP']
dim_hidden = [64, 128]
num_head = 2
wl_grid = [1, 2, 3]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.53 best test acc:0.6958637469586375
# 225.04938745498657
# Best combination for fold 2: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.545 best test acc:0.7664233576642335
# 283.64904975891113
# Best combination for fold 3: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.539 best test acc:0.7518248175182481
# 242.28782057762143
# Best combination for fold 4: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 1, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.559 best test acc:0.7396593673965937
# 202.1275396347046
# Best combination for fold 5: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.51 best test acc:0.7566909975669099
# 294.87159538269043
# Best combination for fold 6: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.576 best test acc:0.754257907542579
# 386.4241905212402
# Best combination for fold 7: {'kernel': ['WL', 'SP'], 'wl': 2, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.56 best test acc:0.7566909975669099
# 373.7307753562927
# Best combination for fold 8: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.527 best test acc:0.7445255474452555
# 399.1997697353363
# Best combination for fold 9: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.514 best test acc:0.6520681265206812
# 382.8763349056244
# Best combination for fold 10: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.479 best test acc:0.7493917274939172
# 396.74280524253845
# Test accuracy mean: 0.7367396593673966
# Test accuracy standard deviation: 0.010621211332950499
# [225.04938745498657, 283.64904975891113, 242.28782057762143, 202.1275396347046, 294.87159538269043, 386.4241905212402, 373.7307753562927, 399.1997697353363, 382.8763349056244, 396.74280524253845]
# time cost: 318.70+/-23.30

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/NCI1/"
kernel_grid = ['WL', 'SP']
dim_hidden = [64, 128]
num_head = 2
wl_grid = [1, 2, 3]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for dim in dim_hidden:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                            # elif val_acc == best_val_acc:
                            #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.53 best test acc:0.6958637469586375
# 225.04938745498657
# Best combination for fold 2: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.545 best test acc:0.7664233576642335
# 283.64904975891113
# Best combination for fold 3: {'kernel': ['WL', 'SP'], 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.539 best test acc:0.7518248175182481
# 242.28782057762143
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2250592/2013879685.py in <module>
#      29                             for bs in bs_grid:
#      30                                 path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], dim, wl, layer, hop, drop, lr, bs)
# ---> 31                                 df = pd.read_csv(path)
#      32                                 val_loss = df.iloc[:, -1].min()
#      33                                 if val_loss < best_val_loss:
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/anaconda3/envs/PyG/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Output_200_Adam/NCI1//fold_4/2_WL_SP_128_1_1_1_0.0_0.001_32/results.csv'

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_Adam/NCI1/"
kernel_grid = ['WL', 'GL', 'SP', 'RW']
wl_grid = [1, 2, 3,4,5]
layer_grid = [1, 2, 3, 4, 5, 6]
dim_hidden = [128, 256]
hop_grid = [1]
bs_grid = [64]
gls = [5]
drop_grid = [0.0]
lr_grid = [0.001]
num_head = 4


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for wl in wl_grid:
        for gl_k in gls:
            for dim in dim_hidden:
                for layer in layer_grid:
                    for hop in hop_grid:
                        for drop in drop_grid:
                            for lr in lr_grid:
                                for bs in bs_grid:
                                    path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, num_head, kernel_grid[0], kernel_grid[1], kernel_grid[2], kernel_grid[3], dim, wl, gl_k, layer, hop, drop)
                                    df = pd.read_csv(path)
                                    val_loss = df.iloc[:, -1].min()
                                    if val_loss < best_val_loss:
                                        best_val_loss = val_loss
                                        best_combination = {'kernel': kernel_grid, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                        best_test_acc = df.iloc[-2, 1]
                                        time = df.iloc[-1,0]
                                    # elif val_acc == best_val_acc:
                                    #     test_acc = df.iloc[-2, 1]
                                    #     if test_acc > best_test_acc:
                            #         best_test_acc = test_acc
                            #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.478 best test acc:0.7591240875912408
# Best combination for fold 2: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.504 best test acc:0.7639902676399026
# Best combination for fold 3: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 4, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.505 best test acc:0.754257907542579
# Best combination for fold 4: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 6, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.557 best test acc:0.6934306569343066
# Best combination for fold 5: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.52 best test acc:0.7761557177615572
# Best combination for fold 6: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.551 best test acc:0.7420924574209246
# Best combination for fold 7: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.552 best test acc:0.7445255474452555
# Best combination for fold 8: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 4, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.521 best test acc:0.7153284671532847
# Best combination for fold 9: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 4, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.538 best test acc:0.6934306569343066
# Best combination for fold 10: {'kernel': ['WL', 'GL', 'SP', 'RW'], 'wl': 5, 'layer': 5, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 64}, bet val loss: 0.489 best test acc:0.7201946472019465
# Test accuracy mean: 0.7362530413625303
# Test accuracy standard deviation: 0.008760475699988385
# time cost: 417.32+/-39.80
