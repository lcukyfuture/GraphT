# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200/MUTAG/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.2174203544855117 best test acc:0.6842105263157895
# 11.194626331329346
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.4181841015815735 best test acc:0.8947368421052632
# 16.956303596496582
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.2876440584659576 best test acc:0.9473684210526316
# 38.41480851173401
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.247274562716484 best test acc:0.7894736842105263
# 42.676448583602905
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_CPU/MUTAG/"
kernel_grid = ['WL']
wl_grid = [3, 4, 5]
layer_grid = [1, 2]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]
dim_hideens = [64]

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for dim_hidden in dim_hideens:
            for wl in wl_grid:
                for layer in layer_grid:
                    for hop in hop_grid:
                        for drop in drop_grid:
                            for lr in lr_grid:
                                for bs in bs_grid:
                                    path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, dim_hidden, kernel, wl, layer, hop, drop, lr, bs)
                                    df = pd.read_csv(path)
                                    val_loss = df.iloc[:, -1].min()
                                    if val_loss < best_val_loss:
                                        best_val_loss = val_loss
                                        best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                        best_test_acc = df.iloc[-2, 1]
                                        time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL', 'wl': 3, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.344 best test acc:0.6842105263157895
# 19.63955283164978
# Best combination for fold 2: {'kernel': 'WL', 'wl': 3, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.528 best test acc:0.8947368421052632
# 20.71178150177002
# Best combination for fold 3: {'kernel': 'WL', 'wl': 4, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.597 best test acc:0.7368421052631579
# 6.526256084442139
# Best combination for fold 4: {'kernel': 'WL', 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.511 best test acc:0.631578947368421
# 14.232266664505005
# Best combination for fold 5: {'kernel': 'WL', 'wl': 3, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.624 best test acc:0.6842105263157895
# 6.690107822418213
# ...

# %%
data = (14.354374647140503, 12.756694555282593, 24.38179039955139, 12.731260061264038, 13.649175643920898, 17.215359210968018, 14.977934837341309, 60.21424221992493, 16.008084297180176, 17.35973811149597)
mean = np.mean(data)
error = np.std(data)/np.sqrt(10)

print(f"{mean} +/- {error}")
# Out:
#   File "<fstring>", line 1
#     (mean.4f)
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### TIME

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200/PTC_MR/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]
dim_hiddens = [32, 64, 128]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for dim_hidden in dim_hiddens:
        for kernel in kernel_grid:
            for wl in wl_grid:
                for layer in layer_grid:
                    for hop in hop_grid:
                        for drop in drop_grid:
                            for lr in lr_grid:
                                for bs in bs_grid:
                                    if dim_hidden == 64:
                                        path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                    else:
                                        path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, dim_hidden, kernel, wl, layer, hop, drop, lr, bs)
                                    df = pd.read_csv(path)
                                    val_loss = df.iloc[:, -1].min()
                                    if val_loss < best_val_loss:
                                        best_val_loss = val_loss
                                        best_combination = {'kernel': kernel, 'dim-hidden': dim_hidden, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                        best_test_acc = df.iloc[-2, 1]
                                        time = df.iloc[-1, 0]
                                    # elif val_acc == best_val_acc:
                                    #     test_acc = df.iloc[-2, 1]
                                    #     if test_acc > best_test_acc:
                                    #         best_test_acc = test_acc
                                    #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'dim-hidden': 64, 'wl': 4, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.6161550283432007 best test acc:0.6
# 33.53134489059448
# Best combination for fold 2: {'kernel': 'WL_GPU', 'dim-hidden': 64, 'wl': 5, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.6397143602371216 best test acc:0.4571428571428571
# 22.62472105026245
# Best combination for fold 3: {'kernel': 'WL_GPU', 'dim-hidden': 64, 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.6734421253204346 best test acc:0.6
# 24.30336546897888
# Best combination for fold 4: {'kernel': 'WL_GPU', 'dim-hidden': 128, 'wl': 5, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.631 best test acc:0.7428571428571429
# 16.646031618118286
# ...

# %% [markdown]
# #### Time

# %%
data = (66.75243926048279, 71.72104072570801, 94.99817609786987, 83.71246981620789, 90.64121627807617, 65.75581455230713, 116.12956953048706, 98.73343515396118, 60.41971969604492, 166.9319553375244)
mean = np.mean(data)
error = np.std(data)/np.sqrt(10)

print(f"{mean} +/- {error}")
# Out:
# 91.57958364486694 +/- 9.515708645384573

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_test/PROTEINS/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.463 best test acc:0.7678571428571429
# 237.23217296600345
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.523 best test acc:0.7946428571428571
# 185.6413071155548
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 1, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.441 best test acc:0.6964285714285714
# 152.35872793197632
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.452 best test acc:0.7297297297297297
# 78.52581572532654
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.459 best test acc:0.6936936936936937
# 159.76273655891418
# ...

# %% [markdown]
# #### Time

# %%
data = (171.81897258758545, 235.75248050689697, 139.93906593322754, 189.93402409553528, 239.01107168197632, 154.12205481529236, 93.33387422561646, 128.9020495414734, 559.9359138011932, 170.1986904144287)
mean = np.mean(data)
error = np.std(data)/np.sqrt(10)

print(f"{mean} +/- {error}")
# Out:
# 208.29481976032258 +/- 39.44543320891754

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_NCI1/NCI1/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4,5]
layer_grid = [1, 2, 3]
hop_grid = [1,2,3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 1, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.557 best test acc:0.7201946472019465
# 253.0179409980774
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.559 best test acc:0.7299270072992701
# 332.47826409339905
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.547 best test acc:0.7469586374695864
# 336.8142156600952
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.565 best test acc:0.7153284671532847
# 303.4376411437988
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.555 best test acc:0.7226277372262774
# 400.5677065849304
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200/ENZYMES/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 1.586 best test acc:0.35
# 45.70170569419861
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 1.369 best test acc:0.3333333333333333
# 98.91488718986513
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 1.408 best test acc:0.3833333333333333
# 79.42492341995239
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 1.588 best test acc:0.3666666666666666
# 73.23576331138611
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 1.409 best test acc:0.45
# 97.49138069152832
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200/AIDS/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.001 best test acc:0.99
# 195.5568521022797
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.001 best test acc:0.995
# 196.49842977523804
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.003 best test acc:0.995
# 134.58813309669495
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.001 best test acc:0.99
# 155.5737476348877
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.062 best test acc:1.0
# 155.52624416351318
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_IMDB_SGD/IMDB-BINARY/"
kernel_grid = ['WL_GPU']
wl_grid = [1, 2]
layer_grid = [1, 2, 3]
hop_grid = [1, 2]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]


test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 1, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.58 best test acc:0.69
# 55.70232582092285
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 1, 'layer': 2, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.616 best test acc:0.73
# 61.75164556503296
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 1, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.467 best test acc:0.71
# 111.38418221473694
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 1, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.505 best test acc:0.77
# 94.05792927742004
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 1, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.461 best test acc:0.75
# 115.94919347763062
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_MUTAG_test/MUTAG/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.211 best test acc:0.7894736842105263
# 36.66314625740051
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.339 best test acc:0.8421052631578947
# 16.360865831375122
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.373 best test acc:0.9473684210526316
# 15.039999723434448
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.281 best test acc:0.8421052631578947
# 16.352476358413696
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.558 best test acc:0.7368421052631579
# 15.24610185623169
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_MUTAG/PTC_MR/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4,5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.1]

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.631 best test acc:0.6571428571428571
# 25.514350652694706
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.654 best test acc:0.6
# 22.0466742515564
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 1, 'hop': 1, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.71 best test acc:0.5428571428571428
# 16.92414093017578
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 4, 'layer': 1, 'hop': 2, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.655 best test acc:0.6857142857142857
# 15.390112400054932
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 3, 'layer': 2, 'hop': 3, 'drop': 0.0, 'lr': 0.1, 'bs': 32}, bet val loss: 0.697 best test acc:0.5588235294117647
# 15.18878173828125
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_MUTAG_test/PROTEINS/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.481 best test acc:0.7232142857142857
# 147.380952835083
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.539 best test acc:0.75
# 150.3231635093689
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.489 best test acc:0.7053571428571429
# 306.53098154067993
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.433 best test acc:0.6846846846846847
# 207.02150201797485
# Best combination for fold 5: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.494 best test acc:0.7027027027027027
# 185.2858784198761
# ...

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the parent directory containing all the subdirectories
parent_dir = "Output_200_MUTAG_test/NCI1/"
kernel_grid = ['WL_GPU']
wl_grid = [3, 4, 5]
layer_grid = [1, 2, 3]
hop_grid = [1, 2, 3]
bs_grid = [32]
drop_grid = [0.0]
lr_grid = [0.001]

test_acc_list = []
time_list = []
for fold in range(1, 11):
    best_val_loss = float('inf')
    best_test_acc = 0
    for kernel in kernel_grid:
        for wl in wl_grid:
            for layer in layer_grid:
                for hop in hop_grid:
                    for drop in drop_grid:
                        for lr in lr_grid:
                            for bs in bs_grid:
                                path = parent_dir + '/fold_{}/{}_{}_{}_{}_{}_{}_{}/results.csv'.format(fold, kernel, wl, layer, hop, drop, lr, bs)
                                df = pd.read_csv(path)
                                val_loss = df.iloc[:, -1].min()
                                if val_loss < best_val_loss:
                                    best_val_loss = val_loss
                                    best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
                                    best_test_acc = df.iloc[-2, 1]
                                    time = df.iloc[-1, 0]
                                # elif val_acc == best_val_acc:
                                #     test_acc = df.iloc[-2, 1]
                                #     if test_acc > best_test_acc:
                                #         best_test_acc = test_acc
                                #         best_combination = {'kernel': kernel, 'wl': wl, 'layer': layer, 'hop': hop, 'drop': drop, 'lr': lr, 'bs': bs}
    print('Best combination for fold {}: {}, bet val loss: {} best test acc:{}'.format(fold, best_combination,best_val_loss,  best_test_acc))
    test_acc_list.append(best_test_acc)
    time_list.append(time)
    print(time)

mean = np.mean(test_acc_list)
std_error = np.std(test_acc_list)/np.sqrt(10)
print(f"Test accuracy mean: {mean}")
print(f"Test accuracy standard deviation: {std_error}")

time_mean = np.mean(time_list)
time_error = np.std(time_list)/np.sqrt(10)
print(time_list)
print(f'time cost: {time_mean:.2f}+/-{time_error:.2f}' )
# Out:
# Best combination for fold 1: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.5062334472894022 best test acc:0.6958637469586375
# 447.0105121135712
# Best combination for fold 2: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 2, 'hop': 1, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.5999514156886878 best test acc:0.6763990267639902
# 294.0288863182068
# Best combination for fold 3: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 3, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.5818708214333387 best test acc:0.6934306569343066
# 412.66866278648376
# Best combination for fold 4: {'kernel': 'WL_GPU', 'wl': 5, 'layer': 3, 'hop': 2, 'drop': 0.0, 'lr': 0.001, 'bs': 32}, bet val loss: 0.5817218834791726 best test acc:0.7007299270072993
# 438.2182846069336
# ...
